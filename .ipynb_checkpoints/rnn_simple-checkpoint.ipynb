# %% [markdown]
# ### Simple RNN
#
# ```
# SimpleRNN(
#     units, # 일반 신경망의 은닉층 노드 개수와 같은 개념
#     activation,
#     input_shape, # ex. (3,1): window size = 3, RNN layer로 한번에 1개의 data 들어감.
# )
# ```

# %% [markdown]
# #### 학습 데이터 생성
# RNN layer의 입력 data는 ```(batch_size, time_steps, input_dim)``` 형태로 시계열 data를 <strong>변형</strong>해 구축
# - batch_size: 전체 시계열 data를 time_step으로 분리했을 때 데이터 총 개수
# - time_step = window_size
# - input_dim: RNN layer로 한번에 들어가는 data 개수

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.layers import SimpleRNN, Dense
from tensorflow.keras import Sequential

# %%
# 시계열 data 생성
x = np.arange(0, 100, 0.1)
y = 0.5 * np.sin(2*x) - np.cos(x/2)

# %%
seq_data = y.reshape(-1,1)

# %%
plt.grid()
plt.xlabel('time')
plt.ylabel('amplitude')
plt.plot(x,y)
plt.show()

# %%
# 학습 data 생성 (window_size = 20, horizion_factor = 1)
w = 20
h = 1

def seq2dataset(seq, w, h):
    x_train = []
    y_train = []
    
    iteration = len(seq) - (w+h) +1
    
    for i in range(iteration):
        x_in = seq[i:i+w]
        y_in = seq[i+w+h-1]
        
        x_train.append(x_in)
        y_train.append(y_in)
        
    return np.array(x_train), np.array(y_train)

(x_train, y_train) = seq2dataset(seq_data, w, h)

# %%
print("seq[20]: ", x_train[1][-1], "==", y_train[0])
# Out:
# seq[20]:  [-0.91870355] == [-0.91870355]

# %%
print(x_train.shape)
print(y_train.shape)
# Out:
# (980, 20, 1)
# (980, 1)

# %%
rnn = Sequential()

rnn.add(SimpleRNN(
    units=128,
    activation='tanh',
    input_shape=(w, 1)
))

rnn.add(Dense(1))

# %%
rnn.compile(optimizer='adam', loss='mse', metrics=['mae']) # mae: 오차의 절대값
rnn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# simple_rnn (SimpleRNN)       (None, 128)               16640
# _________________________________________________________________
# dense (Dense)                (None, 1)                 129
# =================================================================
# Total params: 16,769
# Trainable params: 16,769
# Non-trainable params: 0
# _________________________________________________________________

# %%
hist = rnn.fit(x_train, y_train, epochs=30, validation_split=0.2)
# Out:
# Epoch 1/30
# 25/25 [==============================] - 1s 11ms/step - loss: 0.0671 - mae: 0.1911 - val_loss: 0.0054 - val_mae: 0.0573
# Epoch 2/30
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0035 - mae: 0.0453 - val_loss: 0.0022 - val_mae: 0.0414
# Epoch 3/30
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0011 - mae: 0.0262 - val_loss: 6.4159e-04 - val_mae: 0.0196
# Epoch 4/30
# 25/25 [==============================] - 0s 4ms/step - loss: 4.9313e-04 - mae: 0.0170 - val_loss: 3.7872e-04 - val_mae: 0.0144
# Epoch 5/30
# 25/25 [==============================] - 0s 4ms/step - loss: 3.3482e-04 - mae: 0.0139 - val_loss: 2.1688e-04 - val_mae: 0.0107
# Epoch 6/30
# 25/25 [==============================] - 0s 4ms/step - loss: 2.0561e-04 - mae: 0.0106 - val_loss: 1.4455e-04 - val_mae: 0.0092
# Epoch 7/30
# 25/25 [==============================] - 0s 4ms/step - loss: 1.3738e-04 - mae: 0.0088 - val_loss: 2.9691e-04 - val_mae: 0.0143
# Epoch 8/30
# 25/25 [==============================] - 0s 4ms/step - loss: 2.1819e-04 - mae: 0.0119 - val_loss: 3.0890e-04 - val_mae: 0.0143
# Epoch 9/30
# 25/25 [==============================] - 0s 4ms/step - loss: 3.2586e-04 - mae: 0.0145 - val_loss: 1.7321e-04 - val_mae: 0.0103
# Epoch 10/30
# 25/25 [==============================] - 0s 4ms/step - loss: 1.1075e-04 - mae: 0.0084 - val_loss: 4.8836e-05 - val_mae: 0.0053
# Epoch 11/30
# 25/25 [==============================] - 0s 4ms/step - loss: 7.9102e-05 - mae: 0.0067 - val_loss: 7.7309e-05 - val_mae: 0.0069
# Epoch 12/30
# 25/25 [==============================] - 0s 4ms/step - loss: 9.3452e-05 - mae: 0.0077 - val_loss: 4.0122e-05 - val_mae: 0.0052
# Epoch 13/30
# 25/25 [==============================] - 0s 4ms/step - loss: 4.1793e-05 - mae: 0.0051 - val_loss: 1.3815e-04 - val_mae: 0.0099
# Epoch 14/30
# 25/25 [==============================] - 0s 4ms/step - loss: 1.0775e-04 - mae: 0.0080 - val_loss: 1.4070e-04 - val_mae: 0.0095
# Epoch 15/30
# 25/25 [==============================] - 0s 4ms/step - loss: 7.8813e-05 - mae: 0.0069 - val_loss: 2.7344e-05 - val_mae: 0.0043
# Epoch 16/30
# 25/25 [==============================] - 0s 4ms/step - loss: 6.9469e-05 - mae: 0.0068 - val_loss: 8.7850e-05 - val_mae: 0.0080
# Epoch 17/30
# 25/25 [==============================] - 0s 4ms/step - loss: 1.6922e-04 - mae: 0.0105 - val_loss: 1.0754e-04 - val_mae: 0.0084
# Epoch 18/30
# 25/25 [==============================] - 0s 4ms/step - loss: 2.5120e-04 - mae: 0.0125 - val_loss: 9.2846e-05 - val_mae: 0.0077
# Epoch 19/30
# 25/25 [==============================] - 0s 4ms/step - loss: 2.8748e-04 - mae: 0.0139 - val_loss: 1.7573e-04 - val_mae: 0.0111
# Epoch 20/30
# 25/25 [==============================] - 0s 4ms/step - loss: 7.2534e-05 - mae: 0.0068 - val_loss: 6.8544e-05 - val_mae: 0.0070
# Epoch 21/30
# 25/25 [==============================] - 0s 4ms/step - loss: 5.3277e-05 - mae: 0.0058 - val_loss: 6.5259e-05 - val_mae: 0.0071
# Epoch 22/30
# 25/25 [==============================] - 0s 4ms/step - loss: 3.9715e-05 - mae: 0.0051 - val_loss: 3.4833e-05 - val_mae: 0.0050
# Epoch 23/30
# 25/25 [==============================] - 0s 4ms/step - loss: 8.4752e-05 - mae: 0.0071 - val_loss: 1.9066e-04 - val_mae: 0.0117
# Epoch 24/30
# 25/25 [==============================] - 0s 4ms/step - loss: 8.0725e-05 - mae: 0.0068 - val_loss: 2.2049e-05 - val_mae: 0.0036
# Epoch 25/30
# 25/25 [==============================] - 0s 4ms/step - loss: 1.3584e-05 - mae: 0.0029 - val_loss: 1.0625e-05 - val_mae: 0.0026
# Epoch 26/30
# 25/25 [==============================] - 0s 4ms/step - loss: 1.3612e-05 - mae: 0.0029 - val_loss: 1.8393e-05 - val_mae: 0.0036
# Epoch 27/30
# 25/25 [==============================] - 0s 4ms/step - loss: 2.6187e-05 - mae: 0.0040 - val_loss: 4.8693e-05 - val_mae: 0.0056
# Epoch 28/30
# 25/25 [==============================] - 0s 4ms/step - loss: 4.1613e-05 - mae: 0.0052 - val_loss: 3.3728e-05 - val_mae: 0.0048
# Epoch 29/30
# 25/25 [==============================] - 0s 4ms/step - loss: 2.9601e-05 - mae: 0.0042 - val_loss: 1.8676e-05 - val_mae: 0.0035
# Epoch 30/30
# 25/25 [==============================] - 0s 4ms/step - loss: 1.9146e-05 - mae: 0.0034 - val_loss: 1.0968e-05 - val_mae: 0.0027

# %%
plt.subplot(1,2,1)

plt.title("RNN Loss Value")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.grid()

plt.plot(hist.history["loss"], label="loss")
plt.plot(hist.history["val_loss"], label="val_loss")

plt.subplot(1,2,2)

plt.title("RNN Mae Value")
plt.xlabel("Epochs")
plt.ylabel("Mae")
plt.grid()

plt.plot(hist.history["mae"], label="mae")
plt.plot(hist.history["val_mae"], label="val_mae")

plt.tight_layout()

# %%
from random import Random

rand = Random().randrange(len(x_train))

# %%
x_test = x_train[rand:]
y_test = y_train[rand:]

# %%
pred = rnn.predict(x_test)

# %%
plt.figure(figsize=(10,5))

plt.subplot(1,2,1)
plt.grid()
plt.plot(pred, label='predict', color='green')
plt.legend(loc='best')

plt.subplot(1,2,2)
plt.grid()
plt.plot(y_test, label='y_test')
plt.legend(loc='best')

plt.tight_layout()
plt.show()
