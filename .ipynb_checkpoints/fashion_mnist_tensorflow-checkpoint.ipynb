# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.optimizers import SGD, Adam

# %% [markdown]
# #### Mnist fashion

# %%
fashion_item = {
    0: "T-shirt/top",
    1: "Trouser",
    2: "Pullover",
    3: "Dress",
    4: "Coat",
    5: "Sandal",
    6: "Shift",
    7: "Sneaker",
    8: "Bag",
    9: "Ankle boot",
}

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.fashion_mnist.load_data()

# %%
plt.figure(figsize=(10,10))

for i in range(6):
    plt.subplot(1,6,i+1)
    img = x_train[i]
    plt.imshow(img, cmap='gray')
    item = y_train[i]
    plt.axis('off')
    plt.text(2, -2, fashion_item[item], fontsize=14)
    plt.tight_layout()

plt.show()

# %%
# 데이터 normalization
normal_x_train = x_train / 255.0 * 0.99 + 0.01
normal_x_test = x_test / 255.0 * 0.99 + 0.01

# t data는 sparse categorical cross entropy 를 사용하기에 rescaling X.

# %%
fashion_mnist_model = Sequential([
    Flatten(input_shape=(normal_x_train.shape[1], normal_x_train.shape[2]), name = "Input_layer"),
    Dense(100, activation="relu", name="Hidden_layer"),
    Dense(10, activation="softmax", name="Output_layer"),
])

# %%
fashion_mnist_model.compile(optimizer=Adam(1e-3), loss="sparse_categorical_crossentropy", metrics=['accuracy'])

# %%
fashion_mnist_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Input_layer (Flatten)        (None, 784)               0
# _________________________________________________________________
# Hidden_layer (Dense)         (None, 100)               78500
# _________________________________________________________________
# Output_layer (Dense)         (None, 10)                1010
# =================================================================
# Total params: 79,510
# Trainable params: 79,510
# Non-trainable params: 0
# _________________________________________________________________

# %%
hist = fashion_mnist_model.fit(normal_x_train, y_train, epochs=30, validation_split=0.2)
# Out:
# Epoch 1/30
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.5242 - accuracy: 0.8161 - val_loss: 0.4578 - val_accuracy: 0.8307
# Epoch 2/30
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.3903 - accuracy: 0.8594 - val_loss: 0.4014 - val_accuracy: 0.8564
# Epoch 3/30
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.3527 - accuracy: 0.8709 - val_loss: 0.3725 - val_accuracy: 0.8675
# Epoch 4/30
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.3270 - accuracy: 0.8810 - val_loss: 0.3581 - val_accuracy: 0.8712
# Epoch 5/30
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.3079 - accuracy: 0.8869 - val_loss: 0.3431 - val_accuracy: 0.8760
# Epoch 6/30
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.2935 - accuracy: 0.8905 - val_loss: 0.3430 - val_accuracy: 0.8744
# Epoch 7/30
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.2807 - accuracy: 0.8958 - val_loss: 0.3232 - val_accuracy: 0.8819
# Epoch 8/30
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.2721 - accuracy: 0.8995 - val_loss: 0.3233 - val_accuracy: 0.8825
# Epoch 9/30
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.2602 - accuracy: 0.9027 - val_loss: 0.3415 - val_accuracy: 0.8758
# Epoch 10/30
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.2510 - accuracy: 0.9062 - val_loss: 0.3453 - val_accuracy: 0.8774
# Epoch 11/30
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.2438 - accuracy: 0.9096 - val_loss: 0.3094 - val_accuracy: 0.8889
# Epoch 12/30
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.2343 - accuracy: 0.9128 - val_loss: 0.3241 - val_accuracy: 0.8861
# Epoch 13/30
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.2299 - accuracy: 0.9126 - val_loss: 0.3304 - val_accuracy: 0.8828
# Epoch 14/30
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.2224 - accuracy: 0.9165 - val_loss: 0.3193 - val_accuracy: 0.8911
# Epoch 15/30
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.2172 - accuracy: 0.9179 - val_loss: 0.3263 - val_accuracy: 0.8867
# Epoch 16/30
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.2121 - accuracy: 0.9204 - val_loss: 0.3242 - val_accuracy: 0.8869
# Epoch 17/30
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.2066 - accuracy: 0.9221 - val_loss: 0.3546 - val_accuracy: 0.8800
# Epoch 18/30
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.2009 - accuracy: 0.9240 - val_loss: 0.3578 - val_accuracy: 0.8794
# Epoch 19/30
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.1977 - accuracy: 0.9256 - val_loss: 0.3295 - val_accuracy: 0.8857
# Epoch 20/30
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.1908 - accuracy: 0.9280 - val_loss: 0.3284 - val_accuracy: 0.8898
# Epoch 21/30
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.1855 - accuracy: 0.9310 - val_loss: 0.3402 - val_accuracy: 0.8902
# Epoch 22/30
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.1830 - accuracy: 0.9318 - val_loss: 0.3561 - val_accuracy: 0.8876
# Epoch 23/30
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.1765 - accuracy: 0.9344 - val_loss: 0.3439 - val_accuracy: 0.8927
# Epoch 24/30
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.1743 - accuracy: 0.9348 - val_loss: 0.3410 - val_accuracy: 0.8905
# Epoch 25/30
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.1707 - accuracy: 0.9364 - val_loss: 0.3545 - val_accuracy: 0.8911
# Epoch 26/30
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.1683 - accuracy: 0.9367 - val_loss: 0.3522 - val_accuracy: 0.8958
# Epoch 27/30
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.1636 - accuracy: 0.9383 - val_loss: 0.3479 - val_accuracy: 0.8916
# Epoch 28/30
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.1611 - accuracy: 0.9406 - val_loss: 0.3695 - val_accuracy: 0.8881
# Epoch 29/30
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.1581 - accuracy: 0.9408 - val_loss: 0.3869 - val_accuracy: 0.8844
# Epoch 30/30
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.1563 - accuracy: 0.9414 - val_loss: 0.3707 - val_accuracy: 0.8888

# %%
fashion_mnist_model.evaluate(normal_x_test, y_test)
# Out:
# 313/313 [==============================] - 0s 963us/step - loss: 0.4170 - accuracy: 0.8799
# [0.4169539511203766, 0.8798999786376953]

# %%
plt.subplot(1,2,1)

plt.title("Mnist Fashion MLP Loss Value")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.grid()

plt.plot(hist.history["loss"], label="loss")
plt.plot(hist.history["val_loss"], label="val_loss")

plt.legend(loc='best')

plt.subplot(1,2,2)

plt.title("Mnist Fashion MLP Accuracy Value")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.grid()

plt.plot(hist.history["accuracy"], label="acc")
plt.plot(hist.history["val_accuracy"], label="val_acc")

plt.legend(loc='best')

plt.tight_layout()

# %%
plt.figure(figsize=(15,15))

for i in range(25):
    plt.subplot(5,5,i+1)
    img = x_test[i]
    plt.imshow(img, cmap='gray')
    plt.axis('off')
    
    item_idx = np.argmax(fashion_mnist_model.predict(np.array([normal_x_test[i]])))
    
    predict = fashion_item[item_idx]
    answer = fashion_item[y_test[i]]
    
    plt.text(0, -4, "Predict: %s" % (predict), fontsize=14)
    plt.text(0, -1, "Answer: %s" % (answer), fontsize=14)

plt.show()
